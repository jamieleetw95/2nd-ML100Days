# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
lr = 0.1
iters = 0
previous_step_size = 1

iters_history = [iters]
x_history = [cur_x]

while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x
    cur_x = cur_x - lr * df(prev_x) #Gradient descent
    previous_step_size = abs(cur_x - prev_x) # 取較大的值, Change in x
    iters = iters+1 #iteration count
    print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
     # Store parameters for plotting
    iters_history.append(iters)
    x_history.append(cur_x)
    lr = lr - 0.0001
# Out:
# the learning rate is 0.1
# Iteration 1
# X value is 1.4
# the learning rate is 0.0999
# Iteration 2
# X value is 0.12127999999999983
# the learning rate is 0.0998
# Iteration 3
# X value is -0.900927488
# the learning rate is 0.0997
# Iteration 4
# X value is -1.7182825468928
# the learning rate is 0.0996
# Iteration 5
# X value is -2.3720006635517543
# the learning rate is 0.09949999999999999
# Iteration 6
# X value is -2.8949725315049553
# the learning rate is 0.09939999999999999
# Iteration 7
# X value is -3.3134519922417702
# the learning rate is 0.09929999999999999
# Iteration 8
# X value is -3.6484004265825547
# the learning rate is 0.09919999999999998
# Iteration 9
# X value is -3.9165577819485757
# the learning rate is 0.09909999999999998
# Iteration 10
# X value is -4.131296029566368
# the learning rate is 0.09899999999999998
# Iteration 11
# X value is -4.303299415712227
# the learning rate is 0.09889999999999997
# Iteration 12
# X value is -4.441106791284349
# the learning rate is 0.09879999999999997
# Iteration 13
# X value is -4.551544089326561
# the learning rate is 0.09869999999999997
# Iteration 14
# X value is -4.640069286093498
# the learning rate is 0.09859999999999997
# Iteration 15
# X value is -4.71104762287586
# the learning rate is 0.09849999999999996
# Iteration 16
# X value is -4.767971241169316
# the learning rate is 0.09839999999999996
# Iteration 17
# X value is -4.813634500907194
# the learning rate is 0.09829999999999996
# Iteration 18
# X value is -4.85027395802884
# the learning rate is 0.09819999999999995
# Iteration 19
# X value is -4.879680152671976
# the learning rate is 0.09809999999999995
# Iteration 20
# X value is -4.903286906717734
# the learning rate is 0.09799999999999995
# Iteration 21
# X value is -4.922242673001058
# the learning rate is 0.09789999999999995
# Iteration 22
# X value is -4.937467557627451
# the learning rate is 0.09779999999999994
# Iteration 23
# X value is -4.949698903355522
# the learning rate is 0.09769999999999994
# Iteration 24
# X value is -4.959527737639853
# the learning rate is 0.09759999999999994
# Iteration 25
# X value is -4.967427923252553
# the learning rate is 0.09749999999999993
# Iteration 26
# X value is -4.973779478218305
# the learning rate is 0.09739999999999993
# Iteration 27
# X value is -4.97888723586138
# the learning rate is 0.09729999999999993
# Iteration 28
# X value is -4.9829957797627555
# the learning rate is 0.09719999999999993
# Iteration 29
# X value is -4.986301400176876
# the learning rate is 0.09709999999999992
# Iteration 30
# X value is -4.988961668262527
# the learning rate is 0.09699999999999992
# Iteration 31
# X value is -4.991103104619596
# the learning rate is 0.09689999999999992
# Iteration 32
# X value is -4.9928273229443185
# the learning rate is 0.09679999999999991
# Iteration 33
# X value is -4.994215953222298
# the learning rate is 0.09669999999999991
# Iteration 34
# X value is -4.995334587869106
# the learning rate is 0.09659999999999991
# Iteration 35
# X value is -4.996235945492795
# the learning rate is 0.0964999999999999
# Iteration 36
# X value is -4.996962408012686
# the learning rate is 0.0963999999999999
# Iteration 37
# X value is -4.99754805574784
# the learning rate is 0.0962999999999999
# Iteration 38
# X value is -4.998020300210806
# the learning rate is 0.0961999999999999
# Iteration 39
# X value is -4.998401194450246
# the learning rate is 0.0960999999999999
# Iteration 40
# X value is -4.998708484876909
# the learning rate is 0.09599999999999989
# Iteration 41
# X value is -4.998956455780543
# the learning rate is 0.09589999999999989
# Iteration 42
# X value is -4.999156607561835
# the learning rate is 0.09579999999999989
# Iteration 43
# X value is -4.999318201552987
# the learning rate is 0.09569999999999988
# Iteration 44
# X value is -4.999448697775746
# the learning rate is 0.09559999999999988
# Iteration 45
# X value is -4.999554106761023
# the learning rate is 0.09549999999999988
# Iteration 46
# X value is -4.999639272369667
# the learning rate is 0.09539999999999987
# Iteration 47
# X value is -4.999708099201535
# the learning rate is 0.09529999999999987
# Iteration 48
# X value is -4.9997637354937225
# the learning rate is 0.09519999999999987
# Iteration 49
# X value is -4.999808720255718
# the learning rate is 0.09509999999999987
# Iteration 50
# X value is -4.99984510166308
# the learning rate is 0.09499999999999986
# Iteration 51
# X value is -4.9998745323470954
# the learning rate is 0.09489999999999986
# Iteration 52
# X value is -4.999898346107616
# the learning rate is 0.09479999999999986
# Iteration 53
# X value is -4.999917619685612
# the learning rate is 0.09469999999999985
# Iteration 54
# X value is -4.999933222517157
# the learning rate is 0.09459999999999985
# Iteration 55
# X value is -4.999945856816911
# the learning rate is 0.09449999999999985
# Iteration 56
# X value is -4.9999560898785145
# the learning rate is 0.09439999999999985
# Iteration 57
# X value is -4.999964380109451
# the learning rate is 0.09429999999999984
# Iteration 58
# X value is -4.999971098020809
# the learning rate is 0.09419999999999984
# Iteration 59
# X value is -4.9999765431536884
# the learning rate is 0.09409999999999984
# Iteration 60
# X value is -4.9999809577321646
# the learning rate is 0.09399999999999983
# Iteration 61
# X value is -4.999984537678517
# the learning rate is 0.09389999999999983
# Iteration 62
# X value is -4.999987441502491
# the learning rate is 0.09379999999999983
# Iteration 63
# X value is -4.999989797476624
# the learning rate is 0.09369999999999983
# Iteration 64
# X value is -4.999991709429504
# the learning rate is 0.09359999999999982
# Iteration 65
# X value is -4.999993261424301
# the learning rate is 0.09349999999999982
# Iteration 66
# X value is -4.999994521537957
# the learning rate is 0.09339999999999982
# Iteration 67
# X value is -4.9999955449146665
# the learning rate is 0.09329999999999981
# Iteration 68
# X value is -4.9999963762335895
